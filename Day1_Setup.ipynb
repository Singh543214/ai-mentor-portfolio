# %% [markdown]
# <a href="https://colab.research.google.com/github/Singh543214/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid is a hierarchical model outlining the evolving skill sets required to understand, utilize, develop, and lead with Artificial Intelligence.
#
# *   **Foundational Literacy (Layers 1-2):** Begins with data fluency and literacy (Layer 1), progressing to the ability to effectively use and prompt existing AI tools and applications (Layer 2).
# *   **AI Development & Engineering (Layer 3):** This intermediate level focuses on the technical skills needed to build, customize, and engineer AI models and systems.
# *   **Strategic & Ethical Leadership (Layer 4):** Encompasses understanding AI's business impact, designing AI strategies, and ensuring ethical deployment and governance.
# *   **Research & Innovation (Layer 5):** The apex involves pushing the boundaries of AI, conducting cutting-edge research, and developing novel algorithms and theories.
# *   **Progressive Specialization:** The pyramid illustrates a progression from broad understanding and consumption at the base to highly specialized creation, leadership, and innovation at the top.
